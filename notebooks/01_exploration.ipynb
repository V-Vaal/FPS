# %% [markdown]
# # FPS — Exploration notebook
#
# Initial exploratory data analysis for the Ethereum fraud dataset.

# %%
import pandas as pd
import numpy as np

# TODO: load raw dataset from ../data/raw and start basic EDA
